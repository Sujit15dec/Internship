# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')

# %%
# read an excel file and convert into a dataframe object
df=pd.DataFrame(pd.read_excel("customer_retention_dataset_eda.xlsx"))

# show the dataframe
df
# Out:
#     Gender of respondent   How old are you?   \
# 0                   Male         31-40 years
# 1                 Female         21-30 years
# 2                 Female         21-30 years
# 3                   Male         21-30 years
# 4                 Female         21-30 years
# ..                   ...                 ...
# 264               Female         21-30 years
# 265               Female         31-40 years
# 266               Female         41-50 yaers
# 267               Female  Less than 20 years
# 268               Female         41-50 yaers
#
#     Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
# ..                                  ...
# 264                               Solan
# 265                           Ghaziabad
# 266                          Bangalore
# ...

# %%
df.head()
# Out:
#   Gender of respondent How old are you?  Which city do you shop online from?  \
# 0                 Male       31-40 years                               Delhi
# 1               Female       21-30 years                               Delhi
# 2               Female       21-30 years                       Greater Noida
# 3                 Male       21-30 years                             Karnal
# 4               Female       21-30 years                          Bangalore
#
#    What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   Since How Long You are Shopping Online ?  \
# 0                            Above 4 years
# 1                            Above 4 years
# 2                                3-4 years
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
df.columns
# Out:
# Index(['Gender of respondent', 'How old are you? ',
#        'Which city do you shop online from?',
#        'What is the Pin Code of where you shop online from?',
#        'Since How Long You are Shopping Online ?',
#        'How many times you have made an online purchase in the past 1 year?',
#        'How do you access the internet while shopping on-line?',
#        'Which device do you use to access the online shopping?',
#        'What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        'What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        'What browser do you run on your device to access the website?\t\t\t                                                          ',
#        'Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.dtypes
# Out:
# Gender of respondent                                                    object
# How old are you?                                                        object
# Which city do you shop online from?                                     object
# What is the Pin Code of where you shop online from?                      int64
# Since How Long You are Shopping Online ?                                object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                       --------------  -----
#  0   Gender of respondent                                                                                                                                                                                         269 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Gender of respondent                                                    0
# How old are you?                                                        0
# Which city do you shop online from?                                     0
# What is the Pin Code of where you shop online from?                     0
# Since How Long You are Shopping Online ?                                0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %% [markdown]
# Gender of respondent

# %%
sns.countplot(x='Gender of respondent',data=df)
# Out:
# <AxesSubplot:xlabel='Gender of respondent', ylabel='count'>

# %%
Gender_percent=round((df['Gender of respondent'].value_counts().values[0]/269*100))
Gender_percent
# Out:
# 67

# %%
print(df['Gender of respondent'].value_counts()/269*100)
# Out:
# Female    67.286245
# Male      32.713755
# Name: Gender of respondent, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder

def object_to_int(dataframe_series):
    if dataframe_series.dtype=='object':
        dataframe_series = LabelEncoder().fit_transform(dataframe_series)
    return dataframe_series

# %%
df = df.apply(lambda x: object_to_int(x))
df.head()
# Out:
#    Gender of respondent  How old are you?   \
# 0                     1                  1
# 1                     0                  0
# 2                     0                  0
# 3                     1                  0
# 4                     0                  0
#
#    Which city do you shop online from?  \
# 0                                    2
# 1                                    2
# 2                                    4
# 3                                    6
# 4                                    0
#
#    What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#    Since How Long You are Shopping Online ?  \
# 0                                         3
# ...

# %%
df.head(10)
# Out:
#    Gender of respondent  How old are you?   \
# 0                     1                  1
# 1                     0                  0
# 2                     0                  0
# 3                     1                  0
# 4                     0                  0
# 5                     0                  1
# 6                     1                  2
# 7                     1                  2
# 8                     0                  4
# 9                     0                  1
#
#    Which city do you shop online from?  \
# 0                                    2
# 1                                    2
# 2                                    4
# 3                                    6
# 4                                    0
# 5                                    9
# 6                                    2
# 7                                    2
# 8                                   10
# 9                                    2
#
# ...

# %%
dfcorr=df.corr()
dfcorr
# Out:
#                                                     Gender of respondent  \
# Gender of respondent                                            1.000000
# How old are you?                                                0.046169
# Which city do you shop online from?                             0.080912
# What is the Pin Code of where you shop online f...             -0.260365
# Since How Long You are Shopping Online ?                       -0.057096
# ...                                                                  ...
# Longer delivery period                                          0.060838
# Change in website/Application design                           -0.164818
# Frequent disruption when moving from one page t...             -0.256638
# Website is as efficient as before                               0.055663
# Which of the Indian online retailer would you r...             -0.003372
#
#                                                     How old are you?   \
# ...

# %%
df.describe()
# Out:
#        Gender of respondent  How old are you?   \
# count            269.000000         269.000000
# mean               0.327138           1.330855
# std                0.470042           1.183774
# min                0.000000           0.000000
# 25%                0.000000           0.000000
# 50%                0.000000           1.000000
# 75%                1.000000           2.000000
# max                1.000000           4.000000
#
#        Which city do you shop online from?  \
# count                           269.000000
# mean                              4.494424
# std                               3.187687
# min                               0.000000
# 25%                               2.000000
# 50%                               4.000000
# 75%                               7.000000
# max                              10.000000
#
#        What is the Pin Code of where you shop online from?  \
# count                                         269.000000
# ...

# %%
sns.heatmap(dfcorr,annot=True)
# Out:
# <AxesSubplot:>

# %%
df.isna()
# Out:
#      Gender of respondent  How old are you?   \
# 0                   False              False
# 1                   False              False
# 2                   False              False
# 3                   False              False
# 4                   False              False
# ..                    ...                ...
# 264                 False              False
# 265                 False              False
# 266                 False              False
# 267                 False              False
# 268                 False              False
#
#      Which city do you shop online from?  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# ..                                   ...
# 264                                False
# 265                                False
# ...

# %% [markdown]
# How do you access the internet while shopping on-line

# %%
sns.countplot(df['How do you access the internet while shopping on-line?'],hue=df['Gender of respondent'])
pd.crosstab(df['Gender of respondent'],df['How do you access the internet while shopping on-line?']).apply(lambda r:round((r/r.sum())*100,1),axis=1)
# Out:
# How do you access the internet while shopping on-line?    0     1     2     3
# Gender of respondent
# 0                                                       0.0  14.9  47.0  38.1
# 1                                                       4.5  22.7  64.8   8.0

# %% [markdown]
# Which device do you use to access the online shopping

# %%
sns.countplot(df['Which device do you use to access the online shopping?'],hue=df['Gender of respondent'])
pd.crosstab(df['Gender of respondent'],df['Which device do you use to access the online shopping?']).apply(lambda r:round((r/r.sum())*100,1),axis=1)
# Out:
# Which device do you use to access the online shopping?     0     1     2     3
# Gender of respondent
# 0                                                        8.8  35.4  55.8   0.0
# 1                                                       15.9  25.0  45.5  13.6

# %% [markdown]
# How many times you have made an online purchase in the past 1 year

# %%
sns.distplot(df['How many times you have made an online purchase in the past 1 year?'],bins=10)
# Out:
# <AxesSubplot:xlabel='How many times you have made an online purchase in the past 1 year?', ylabel='Density'>

# %%
sns.countplot(df['How many times you have made an online purchase in the past 1 year?'],hue=df['Gender of respondent'])
pd.crosstab(df['Gender of respondent'],df['How many times you have made an online purchase in the past 1 year?']).apply(lambda r:round((r/r.sum())*100,1),axis=1)
# Out:
# How many times you have made an online purchase in the past 1 year?     0  \
# Gender of respondent
# 0                                                                    13.3
# 1                                                                     5.7
#
# How many times you have made an online purchase in the past 1 year?     1  \
# Gender of respondent
# 0                                                                     0.0
# 1                                                                    11.4
#
# How many times you have made an online purchase in the past 1 year?     2  \
# Gender of respondent
# 0                                                                    26.0
# 1                                                                    18.2
#
# How many times you have made an online purchase in the past 1 year?     3  \
# Gender of respondent
# 0                                                                    19.9
# ...

# %%
plt.figure(figsize=(20,18))
sns.heatmap(df.corr(),cmap='summer')
# Out:
# <AxesSubplot:>

# %% [markdown]
# What is the Pin Code of where you shop online from

# %%
sns.countplot(x='What is the Pin Code of where you shop online from?',data=df)
# Out:
# <AxesSubplot:xlabel='What is the Pin Code of where you shop online from?', ylabel='count'>

# %%
sns.boxplot(df['What is the Pin Code of where you shop online from?'])
# Out:
# <AxesSubplot:xlabel='What is the Pin Code of where you shop online from?'>

# %% [markdown]
# Since How Long You are Shopping Online

# %%
sns.distplot(df['Since How Long You are Shopping Online ?'],bins=5)
# Out:
# <AxesSubplot:xlabel='Since How Long You are Shopping Online ?', ylabel='Density'>

# %% [markdown]
# All relevant information on listed products must be stated clearly

# %%
sns.countplot(df['All relevant information on listed products must be stated clearly'],hue=df['Gender of respondent'])
pd.crosstab(df['Gender of respondent'],df['All relevant information on listed products must be stated clearly']).apply(lambda r:round((r/r.sum())*100,1),axis=1)
# Out:
# All relevant information on listed products must be stated clearly     0    1  \
# Gender of respondent
# 0                                                                   47.0  2.2
# 1                                                                   53.4  9.1
#
# All relevant information on listed products must be stated clearly     2    3
# Gender of respondent
# 0                                                                   44.8  6.1
# 1                                                                   29.5  8.0

# %% [markdown]
# Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)

# %%
sns.countplot(df['Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'],hue=df['Gender of respondent'])
pd.crosstab(df['Gender of respondent'],df['Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'])
# Out:
# Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)   0  \
# Gender of respondent
# 0                                                                                                        41
# 1                                                                                                        53
#
# Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)    1  \
# Gender of respondent
# 0                                                                                                        116
# 1                                                                                                         33
#
# Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)   2  \
# Gender of respondent
# 0                                                                                                        10
# ...

# %% [markdown]
# Shopping online is convenient and flexible

# %%
sns.countplot(df['Shopping online is convenient and flexible'],hue=df['Gender of respondent'])
pd.crosstab(df['Gender of respondent'],df['Shopping online is convenient and flexible']).apply(lambda r:round((r/r.sum())*100,1),axis=1)
# Out:
# Shopping online is convenient and flexible     0    1     2     3
# Gender of respondent
# 0                                           28.2  2.2  60.8   8.8
# 1                                           30.7  9.1  40.9  19.3

# %% [markdown]
# Return and replacement policy of the e-tailer is important for purchase decision

# %%
sns.countplot(df['Return and replacement policy of the e-tailer is important for purchase decision'],hue=df['Gender of respondent'])
pd.crosstab(df['Gender of respondent'],df['Return and replacement policy of the e-tailer is important for purchase decision']).apply(lambda r:round((r/r.sum())*100,1),axis=1)
# Out:
# Return and replacement policy of the e-tailer is important for purchase decision     0  \
# Gender of respondent
# 0                                                                                 15.5
# 1                                                                                 26.1
#
# Return and replacement policy of the e-tailer is important for purchase decision     1  \
# Gender of respondent
# 0                                                                                  5.0
# 1                                                                                 12.5
#
# Return and replacement policy of the e-tailer is important for purchase decision     2
# Gender of respondent
# 0                                                                                 79.6
# 1                                                                                 61.4

# %% [markdown]
# Getting value for money spent

# %%
sns.countplot(df['Getting value for money spent'],hue=df['Gender of respondent'])
pd.crosstab(df['Gender of respondent'],df['Getting value for money spent']).apply(lambda r:round((r/r.sum())*100,1),axis=1)
# Out:
# Getting value for money spent     0     1     2
# Gender of respondent
# 0                              56.4  34.8   8.8
# 1                              53.4  21.6  25.0

# %% [markdown]
# Visual appealing web-page layout

# %%
sns.countplot(df['Visual appealing web-page layout'],hue=df['Gender of respondent'])
pd.crosstab(df['Gender of respondent'],df['Visual appealing web-page layout']).apply(lambda r:round((r/r.sum())*100,1),axis=1)
# Out:
# Visual appealing web-page layout     0     1    2     3     4    5    6    7  \
# Gender of respondent
# 0                                 18.2  38.1  5.5   6.6   0.6  4.4  8.8  2.2
# 1                                 12.5  20.5  4.5  27.3  11.4  8.0  4.5  9.1
#
# Visual appealing web-page layout    8    9
# Gender of respondent
# 0                                 7.7  7.7
# 1                                 1.1  1.1

# %% [markdown]
# Quickness to complete purchase

# %%
sns.countplot(df['Gender of respondent'],hue=df['Quickness to complete purchase'])
pd.crosstab(df['Quickness to complete purchase'],df['Gender of respondent']).apply(lambda r:round((r/r.sum())*100,1),axis=1)
# Out:
# Gender of respondent               0     1
# Quickness to complete purchase
# 0                               69.7  30.3
# 1                               89.2  10.8
# 2                               73.3  26.7
# 3                               27.7  72.3
# 4                               93.3   6.7
# 5                               80.0  20.0
# 6                               80.0  20.0
# 7                               71.4  28.6
# 8                               60.0  40.0

# %% [markdown]
# Privacy of customers’ information

# %%
sns.countplot(df['Privacy of customers’ information'],hue=df['Gender of respondent'])
pd.crosstab(df['Gender of respondent'],df['Privacy of customers’ information']).apply(lambda r:round((r/r.sum())*100,1),axis=1)
# Out:
# Privacy of customers’ information    0     1     2    3     4     5    6   \
# Gender of respondent
# 0                                  30.4  22.1   6.1  5.5   0.6   6.6  3.9
# 1                                  18.2  15.9  15.9  4.5  11.4  13.6  0.0
#
# Privacy of customers’ information   7    8    9    10
# Gender of respondent
# 0                                  7.7  6.6  4.4  6.1
# 1                                  1.1  3.4  8.0  8.0

# %% [markdown]
# Ease of navigation in website

# %%
sns.countplot(df['Ease of navigation in website'],hue=df['Gender of respondent'])
pd.crosstab(df['Gender of respondent'],df['Ease of navigation in website']).apply(lambda r:round((r/r.sum())*100,1),axis=1)
# Out:
# Ease of navigation in website     0    1     2    3
# Gender of respondent
# 0                              34.3  0.0  59.7  6.1
# 1                              48.9  5.7  37.5  8.0

# %% [markdown]
# Which of the Indian online retailer would you recommend to a friend

# %%
sns.countplot(df['Which of the Indian online retailer would you recommend to a friend?'],hue=df['Gender of respondent'])
pd.crosstab(df['Gender of respondent'],df['Which of the Indian online retailer would you recommend to a friend?']).apply(lambda r:round((r/r.sum())*100,1),axis=1)
# Out:
# Which of the Indian online retailer would you recommend to a friend?     0  \
# Gender of respondent
# 0                                                                     26.0
# 1                                                                     36.4
#
# Which of the Indian online retailer would you recommend to a friend?     1  \
# Gender of respondent
# 0                                                                     23.2
# 1                                                                     22.7
#
# Which of the Indian online retailer would you recommend to a friend?    2  \
# Gender of respondent
# 0                                                                     7.7
# 1                                                                     1.1
#
# Which of the Indian online retailer would you recommend to a friend?     3  \
# Gender of respondent
# 0                                                                     12.2
# ...
